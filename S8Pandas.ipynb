# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('housing.csv')

# %%
df1.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df1.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#To find the shape of the data?
df1.shape
# Out:
# (21612, 22)

# %%
ascending = df1.sort_values('price', ascending=True)
ascending
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000    75000         1       0.00          670
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# ...           ...              ...      ...       ...        ...          ...
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
#
# ...

# %%
#To look the data in the columns waterfront
df1['waterfront']
# Out:
# 0        0
# 1        0
# 2        0
# 4        0
# 5        0
#         ..
# 21608    0
# 21609    0
# 21610    0
# 21611    0
# 21612    0
# Name: waterfront, Length: 21612, dtype: int64

# %%
#To get the todal values
#How many houses have a waterfront?
df1['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
#To get the complete row of which has the max price
df1[df1['price']==df1['price'].max()]
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
#To get the counts of houses which has more than 3 bedrooms
df1[df1['bedrooms']<3].count()
# Out:
# id               2972
# date             2972
# price            2972
# bedrooms         2972
# bathrooms        2972
# sqft_living      2972
# sqft_lot         2972
# floors           2972
# waterfront       2972
# view             2972
# condition        2972
# grade            2972
# sqft_above       2972
# sqft_basement    2972
# yr_built         2972
# yr_renovated     2972
# zipcode          2972
# lat              2972
# long             2972
# sqft_living15    2972
# sqft_lot15       2972
# dtype: int64

# %%
#Filtering data based on conditions
df1[df1['price']==7700000]['zipcode']
# Out:
# 7252    98102
# Name: zipcode, dtype: int64

# %%
#Which zip code has the costliest house?

# %%
df1[df1['price']== df1['price'].max()]['zipcode']
# Out:
# 7252    98102
# Name: zipcode, dtype: int64

# %%
#29. Create a new column with the floor area(sqft_living, sqft_lot, sqft_above, sqft_basement, all combined in one column).

df1['Floor Area'] = df1['sqft_living'] + df1['sqft_lot'] + df1['sqft_basement'] +df1['sqft_above']
df1['Floor Area']
# Out:
# 0          8010
# 1         12382
# 2         11540
# 4         11440
# 5        112770
#           ...
# 21608      4191
# 21609     10433
# 21610      3390
# 21611      5588
# 21612      3116
# Name: Floor Area, Length: 21612, dtype: int64

# %%
#What is the difference between the above code and this line of code
df1['sqft_living'] + df1['sqft_lot'] + df1['sqft_basement'] +df1['sqft_above']
# Out:
# 0         8010
# 1        12382
# 2        11540
# 3         8920
# 4        11440
#          ...
# 21608     4191
# 21609    10433
# 21610     3390
# 21611     5588
# 21612     3116
# Length: 21613, dtype: int64

# %%
df1
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %% [markdown]
# # iloc function :
#     The iloc indexer allows you to select rows and columns by integer position.

# %%
df1.iloc[:100, :]
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000  221900         3       1.00         1180
# 1   6414100192  20141209T000000  538000         3       2.25         2570
# 2   5631500400  20150225T000000  180000         2       1.00          770
# 3   2487200875  20141209T000000  604000         4       3.00         1960
# 4   1954400510  20150218T000000  510000         3       2.00         1680
# ..         ...              ...     ...       ...        ...          ...
# 95  1483300570  20140908T000000  905000         4       2.50         3300
# 96  3422049190  20150330T000000  247500         3       1.75         1960
# 97  1099611230  20140912T000000  199000         4       1.50         1160
# 98   722079104  20140711T000000  314000         3       1.75         1810
# 99  7338200240  20140516T000000  437500         3       2.50         2320
#
#     sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# ...

# %%
selected_rows_list = df1.iloc[[1, 3, 4]]
selected_rows_list
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 1      7242     2.0           0     0  ...        2170            400
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  Floor Area
# 1        7639       12382
# 3        5000        8920
# 4        7503       11440
#
# ...

# %% [markdown]
# # LOC function :
#     The loc function in Pandas is primarily used for label-based data selection.

# %%
filtered_data = df1.loc[df1['bedrooms'] > 3]
filtered_data
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 14     1175000570  20150312T000000   530000         5       2.00         1810
# 15     9297300055  20150124T000000   650000         4       3.00         2950
# 17     6865200140  20140529T000000   485000         4       1.00         1600
# ...           ...              ...      ...       ...        ...          ...
# 21599  7202300110  20140915T000000   810000         4       3.00         3990
# 21600   249000205  20141015T000000  1537000         5       3.75         4470
# 21605  3448900210  20141014T000000   610685         4       2.50         2520
# 21606  7936000429  20150326T000000  1007500         4       3.50         3510
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
#
# ...

# %%
selected_data = df1.loc[1:100, ['price', 'floors']]
selected_data
# Out:
#        price  floors
# 1     538000     2.0
# 2     180000     1.0
# 3     604000     1.0
# 4     510000     1.0
# 5    1225000     1.0
# ..       ...     ...
# 96    247500     1.0
# 97    199000     1.0
# 98    314000     1.0
# 99    437500     2.0
# 100   850830     1.5
#
# [100 rows x 2 columns]

# %%
#Create a separate data frame that satisfies the conditions below.

#1. Houses built before 1980
#2. Have more than 2 bedrooms
#3. Have more than 2 floors.

# %%
new=df1.loc[(df1["yr_built"] < 1980) & (df1['floors'] > 2) & (df1['bedrooms'] > 2)]

# %%
new
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 518    4386700135  20141114T000000  2250000         4       2.25         4760
# 759     770000045  20141024T000000   405600         5       1.50         2830
# 960    7578200310  20141112T000000   650000         4       2.00         2208
# 1296   5458800125  20140514T000000   925000         4       2.50         2190
# 1350   7234600786  20140511T000000   842500         4       2.50         2160
# ...           ...              ...      ...       ...        ...          ...
# 18535  3667500015  20140925T000000   770000         4       3.50         3680
# 18631  1337800665  20140811T000000  1325000         4       3.25         2850
# 19068  6613001241  20140811T000000  1415000         4       3.00         3110
# 19188  7942601475  20140520T000000   345600         5       3.50         2800
# 19272  1337300145  20140721T000000  1800000         4       2.50         3320
#
# ...

# %%
avg_price_by_zipcode= df1.groupby('zipcode')['price'].mean()
avg_price_by_zipcode
# Out:
# zipcode
# 98001    2.808047e+05
# 98002    2.342840e+05
# 98003    2.941113e+05
# 98004    1.355927e+06
# 98005    8.101649e+05
#              ...
# 98177    6.761854e+05
# 98178    3.106128e+05
# 98188    2.890783e+05
# 98198    3.028789e+05
# 98199    7.918208e+05
# Name: price, Length: 70, dtype: float64

# %%
#Converting scientific notations
# Convert to millions
avg_price_by_zipcode_millions = (avg_price_by_zipcode / 1_000_000).round(2).astype(str) + '$M'
avg_price_by_zipcode_millions
# Out:
# zipcode
# 98001    0.28$M
# 98002    0.23$M
# 98003    0.29$M
# 98004    1.36$M
# 98005    0.81$M
#           ...
# 98177    0.68$M
# 98178    0.31$M
# 98188    0.29$M
# 98198     0.3$M
# 98199    0.79$M
# Name: price, Length: 70, dtype: object

# %%
#Multiple groupby
df1.groupby('zipcode').agg({'price': ['mean', 'sum', 'std']})
# Out:
#                 price
#                  mean        sum            std
# zipcode
# 98001    2.808047e+05  101651298   98979.230092
# 98002    2.342840e+05   46622523   52041.448659
# 98003    2.941113e+05   82351158  107597.662236
# 98004    1.355927e+06  429828890  745820.087617
# 98005    8.101649e+05  136107700  268753.725415
# ...               ...        ...            ...
# 98177    6.761854e+05  172427275  435849.885258
# 98178    3.106128e+05   81380542  161044.746227
# 98188    2.890783e+05   39314655  103106.579944
# 98198    3.028789e+05   84806087  154799.271902
# 98199    7.918208e+05  251007204  397868.262857
#
# [70 rows x 3 columns]

# %%
#To drop a column
df1.drop(columns=['floor size'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23208\3342782373.py in <module>
#       1 #To drop a column
# ----> 2 df1.drop(columns=['floor size'], inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df1.drop(columns=['Floor Area'])
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df1.drop(index=3)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# ...           ...              ...      ...       ...        ...          ...
# 21608   263000018  20140521T000000   360000         3       2.50         1530
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
# 21610  1523300141  20140623T000000   402101         2       0.75         1020
# 21611   291310100  20150116T000000   400000         3       2.50         1600
# 21612  1523300157  20141015T000000   325000         2       0.75         1020
#
# ...

# %%
df1
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df1.drop(index=3, inplace=True)

# %%
df1
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# ...           ...              ...      ...       ...        ...          ...
# 21608   263000018  20140521T000000   360000         3       2.50         1530
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
# 21610  1523300141  20140623T000000   402101         2       0.75         1020
# 21611   291310100  20150116T000000   400000         3       2.50         1600
# 21612  1523300157  20141015T000000   325000         2       0.75         1020
#
# ...

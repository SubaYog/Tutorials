# %%
import numpy as np
import pandas as pd

# %%
#For date-time

from datetime import datetime

# %%
df=pd.read_csv('Walmart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
#The default date format is "YYYY-MM-DD"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
df1=pd.read_csv('Walmart.csv',parse_dates=["Date"])

# %%
df1
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
New=df1[["Date","Weekly_Sales"]] #What does it do

# %%
#To get the year alone from the data
df1["Year"]=df1.Date.dt.year
df1["Year"].unique()
# Out:
# array([2010, 2011, 2012], dtype=int64)

# %%
df1["Month"]=df1.Date.dt.month
df1["Month"]
# Out:
# 5126     1
# 5485     1
# 5484     1
# 4679     1
# 407      1
#         ..
# 4816    12
# 4817    12
# 3576    12
# 2478    12
# 3511    12
# Name: Month, Length: 6435, dtype: int64

# %%
df1
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 5126     36 2012-01-06     306005.53             0        80.74       3.567
# 5485     39 2011-01-28    1158698.44             0        47.94       3.010
# 5484     39 2011-01-21    1243370.74             0        50.25       3.016
# 4679     33 2012-01-27     236920.49             0        56.33       3.675
# 407       3 2012-01-06     432268.53             0        81.55       3.501
# ...     ...        ...           ...           ...          ...         ...
# 4816     34 2011-12-16    1151052.86             0        32.31       3.149
# 4817     34 2011-12-23    1593655.96             0        32.45       3.103
# 3576     26 2010-12-02    1015684.09             1        18.14       2.771
# 2478     18 2010-12-31     887907.01             1        26.10       3.177
# 3511     25 2011-12-08     667130.48             0        70.93       3.812
#
#              CPI  Unemployment  Year  Month  Week
# ...

# %% [markdown]
# # Other date functions:
#                 dt.year, dt.month, dt.day, dt.hour, dt.minute, and dt.second

# %% [markdown]
# # isocalendar() :
#     function in Python
#     ISO Year: The year according to the ISO standard 8601 and ISO standard 2015.
#     ISO years always start with Monday, and Thursday is considered the middle day of the week.
#     ISO Week Number: The week number within the ISO year.
#     ISO weeks can have either 52 full weeks or 53 full weeks.
#     ISO Weekday: The weekday corresponding to the date.
#     In the ISO system, Monday is represented as 1, Tuesday as 2, and so on, with Sunday as 7.

# %% [markdown]
# ISO calendar system provides a standardized way to represent time

# %%
df1['Week'] = df1.Date.dt.isocalendar().week 
df1['Week'].unique()
# Out:
# <IntegerArray>
# [ 1,  4,  3,  2,  7,  5,  6,  8, 11, 12,  9, 10, 13, 17, 16, 14, 15, 21, 20,
#  19, 18, 22, 24, 26, 23, 25, 28, 30, 29, 27, 34, 33, 35, 32, 31, 37, 39, 38,
#  36, 42, 43, 41, 40, 45, 46, 44, 47, 51, 52, 48, 50, 49]
# Length: 52, dtype: UInt32

# %%
df1.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment', 'Year', 'Month', 'Week'],
#       dtype='object')

# %%
df1['Store'].nunique()
# Out:
# 45

# %%
weekly_sales = df1['Weekly_Sales'].groupby(df1['Store']).mean()
weekly_sales
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
weekly_sales_2011 = df1[df1.Year==2011]['Weekly_Sales'].groupby(df1['Week']).mean()
weekly_sales_2011
# Out:
# Week
# 1     1.011528e+06
# 2     9.038595e+05
# 3     9.034366e+05
# 4     8.799967e+05
# 6     1.052969e+06
# 7     1.082581e+06
# 8     9.805747e+05
# 9     1.083822e+06
# 11    9.971628e+05
# 12    9.528044e+05
# 13    1.034819e+06
# 15    1.040321e+06
# 16    1.081704e+06
# 17    9.673341e+05
# 18    1.067010e+06
# 19    1.009914e+06
# 20    9.788133e+05
# 21    1.006521e+06
# 22    1.041377e+06
# 24    1.054390e+06
# 25    1.019647e+06
# 26    9.505731e+05
# 27    1.049149e+06
# 28    1.011465e+06
# 29    1.006098e+06
# 30    9.707394e+05
# 31    1.041630e+06
# 33    1.042608e+06
# 34    1.053710e+06
# 36    1.039183e+06
# 37    1.103946e+06
# 38    9.492910e+05
# 39    9.376851e+05
# 40    1.059327e+06
# 41    9.861071e+05
# 42    1.018199e+06
# 43    1.019018e+06
# 44    1.021817e+06
# 45    1.077205e+06
# 46    1.031977e+06
# 47    1.479858e+06
# 49    1.027768e+06
# 50    1.335238e+06
# 51    1.711072e+06
# 52    1.023166e+06
# Name: Weekly_Sales, dtype: float64

# %%
store6 = df1[df1.Store == 6]
# there are about 45 different stores in this dataset.

sales6 = pd.DataFrame(store6.Weekly_Sales.groupby(store6.index).sum())
sales6
# Out:
#      Weekly_Sales
# 715    1652635.10
# 716    1606283.86
# 717    1567138.07
# 718    1432953.21
# 719    1601348.82
# ..            ...
# 853    1369131.46
# 854    1518177.71
# 855    1459396.84
# 856    1436883.99
# 857    1431426.34
#
# [143 rows x 1 columns]

# %%
#Write the above data to csv data frame
output_file = "store_6_weeklysales.csv"

sales6.to_csv(output_file, index=False)

# %%
# To get the sales of particular dates eg:2010-05-02, 2010-06-02

# %%
start_date = '2010-05-02'
end_date = '2010-06-02'
filtered_sales_df = df1[(df1['Date'] >= start_date) & (df1['Date'] <= end_date)]
filtered_sales_df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 2470     18 2010-05-11    1089530.94             0        42.05       2.938
# 5735     41 2010-05-21    1163234.33             0        50.59       2.776
# 5736     41 2010-05-28    1246654.24             0        56.97       2.737
# 5759     41 2010-05-11    1163878.49             0        46.74       2.729
# 588       5 2010-05-28     310013.11             0        79.81       2.759
# ...     ...        ...           ...           ...          ...         ...
# 1017      8 2010-05-28     868041.56             0        74.71       2.759
# 5187     37 2010-05-11     539683.42             0        62.72       2.689
# 4580     33 2010-05-03     291484.89             0        59.17       2.877
# 1001      8 2010-05-02    1004137.09             0        34.14       2.572
# 1005      8 2010-05-03     881503.95             0        45.64       2.625
#
#              CPI  Unemployment  Year  Month  Week
# ...

# %%
filtered_sales_df.nunique()
# Out:
# Store            45
# Date              6
# Weekly_Sales    270
# Holiday_Flag      1
# Temperature     208
# Fuel_Price       54
# CPI              90
# Unemployment     90
# Year              1
# Month             1
# Week              5
# dtype: int64

# %%
weekly_sales = filtered_sales_df.groupby(['Store', pd.Grouper(key='Date', freq='W')])['Weekly_Sales'].sum()

# Print the weekly sales for each store
for store, weekly_sales_data in weekly_sales.groupby('Store'):
    print(f"Store {store}:")
    print(weekly_sales_data)
    print("\n")
# Out:
# Store 1:
# Store  Date
# 1      2010-05-02    1643690.90
#        2010-05-09    1554806.68
#        2010-05-16    3045910.78
#        2010-05-23    1399662.07
#        2010-05-30    1432069.95
# Name: Weekly_Sales, dtype: float64
#
#
# Store 2:
# Store  Date
# 2      2010-05-02    2136989.46
#        2010-05-09    1991013.13
#        2010-05-16    3819813.77
#        2010-05-23    1896937.10
#        2010-05-30    1957113.89
# Name: Weekly_Sales, dtype: float64
#
#
# Store 3:
# Store  Date
# 3      2010-05-02    461622.22
#        2010-05-09    415202.04
#        2010-05-16    807533.50
#        2010-05-23    343763.17
#        2010-05-30    350089.23
# Name: Weekly_Sales, dtype: float64
#
#
# Store 4:
# Store  Date
# 4      2010-05-02    2135143.87
#        2010-05-09    1971057.44
#        2010-05-16    3888713.07
#        2010-05-23    1903752.60
#        2010-05-30    1857533.70
# Name: Weekly_Sales, dtype: float64
#
#
# Store 5:
# Store  Date
# 5      2010-05-02    317173.10
# ...

# %%
weekly_sales = df1.groupby(['Store', pd.Grouper(key='Date', freq='Y')])['Weekly_Sales'].sum()

# Print the weekly sales for each store
for store, weekly_sales_data in weekly_sales.groupby('Store'):
    print(f"Store {store}:")
    print(weekly_sales_data)
    print("\n")
# Out:
# Store 1:
# Store  Date
# 1      2010-12-31    73278832.00
#        2011-12-31    80921918.83
#        2012-12-31    68202058.02
# Name: Weekly_Sales, dtype: float64
#
#
# Store 2:
# Store  Date
# 2      2010-12-31    95277864.19
#        2011-12-31    98607881.42
#        2012-12-31    81496695.37
# Name: Weekly_Sales, dtype: float64
#
#
# Store 3:
# Store  Date
# 3      2010-12-31    18745419.00
#        2011-12-31    20816876.57
#        2012-12-31    18024439.50
# Name: Weekly_Sales, dtype: float64
#
#
# Store 4:
# Store  Date
# 4      2010-12-31    9.568047e+07
#        2011-12-31    1.110923e+08
#        2012-12-31    9.277119e+07
# Name: Weekly_Sales, dtype: float64
#
#
# Store 5:
# Store  Date
# 5      2010-12-31    14836030.77
#        2011-12-31    16470820.00
#        2012-12-31    14168838.13
# Name: Weekly_Sales, dtype: float64
#
#
# Store 6:
# Store  Date
# 6      2010-12-31    76912320.69
#        2011-12-31    80528762.95
#        2012-12-31    66315047.00
# ...
